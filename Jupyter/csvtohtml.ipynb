# %%
import pandas as pd
import csv
import path

# %%
df = pd.read_csv('cities.csv')
df
# Out:
#                       City  Cloudiness Country        Date  Humidity    Lat  \
# 0    Los Llanos de Aridane          75      ES  1578187952        59  28.66
# 1                Saskylakh           0      RU  1578187953        94  71.97
# 2                  Rikitea          67      PF  1578187953        80 -23.12
# 3                  Mataura         100      NZ  1578187953        68 -46.19
# 4            San Cristobal          19      HN  1578187953        96  14.68
# ..                     ...         ...     ...         ...       ...    ...
# 539             Ridgecrest           1      US  1578188086        50  35.62
# 540                Kavieng         100      PG  1578188086        71  -2.57
# 541                   Ibra           0      OM  1578188086        82  22.69
# 542        Rodrigues Alves         100      BR  1578188087        84  -7.74
# 543               Sri Aman          75      MY  1578188087        88   1.24
#
#         Lng  Max Temp  Wind Speed
# ...

# %%
df.to_html('cities.html')
